# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Experiment of Predicting The Contribution of a Player
# Oyuncu bazlı veride düşük accuracy almamız çok normal, çünkü voleybol takım oyunu: bir oyuncu, çok iyi performans gösterdiği halde takım maçı kaybedebilir veya çok kötü performans gösterdiği halde takım maçı kazanabilir. O yüzden oyuncunun performasını kullanarak maç sonucunu tamin etmek yerine oyuncunun takıma katkısını tahmin edelim. Çünkü bu değer her oyuncu için bireysel bir değer, maç sonucu gibi kolektif oluşturulan bir değer değil. Regresyon ile oyuncuların tüm özelliklerini tahmin etmeye çalışacağız.
#
# Verimizdeki bir oyuncu gözümüze çarptı, FGCU (ASUN) takımından Lockey, Chelsey. 11/22/2019 tarihinde girdiği voleybol maçında 0.0 kill fakat 52.0 asist puanı var. Bu oyuncu, takımın kazandığı 52 sayıya yardım etmiş.
# ### Calculate Contribution of a Player

# %%
# load the data
team_df= pd.read_parquet('parquet_data/team_df_missing_handled.parquet')
player_df= pd.read_parquet('parquet_data/player_df_undersampled.parquet')# player veri seti ile team veri setini 'name' (team_name yerine) ve 'Date' kolonları üzerinden birleştirin

# %%
# Histogram çizme
plt.hist(player_df['Assists'], bins=10, edgecolor='black')
plt.title('Asist Dağılımı (Histogram)')
plt.xlabel('Asist Değeri')
plt.ylabel('Frekans')
plt.show()

# %% [markdown]
# Logarithmic conversion: Converting the assist values logarithmically can achieve a smoother distribution by compressing excessively high values. Thus, our model can learn the assist column well.

# %%
player_df['Assists'] = np.log1p(player_df['Assists'])  # log(assists + 1) dönüşümü
#team_df['Assists'] = np.log1p(team_df['Assists'])  # log(assists + 1) dönüşümü
plt.hist(player_df['Assists'], bins=10, edgecolor='black')
plt.title('Asist Dağılımı (Histogram)')
plt.xlabel('Asist Değeri')
plt.ylabel('Frekans')
plt.show()

# %%
# Eğer tarih formatı 'dd/mm/yyyy' ise
player_df['Date'] = pd.to_datetime(player_df['Date'], format='%m/%d/%Y')
team_df['Date'] = pd.to_datetime(team_df['Date'], format='%m/%d/%Y')

# %%
# Team_df'teki duplicaleri droplayalım
grouped = team_df.groupby(['name', 'Date', 'Opponent'])
# Her grup için eleman sayısı
group_sizes = grouped.size()
two_element_groups = group_sizes[group_sizes == 2]

# 2 elemanlı grupların içerdiği indeksleri bulma
# grouped.indices bu grupların indekslerini döndürür
two_element_indices = [index for group in two_element_groups.index for index in grouped.get_group(group).index]

# Orijinal veri setinden bu indeksleri drop etme
team_df_dropped = team_df.drop(two_element_indices)

# %%
# find the matches that the player is playing from tema_df
merged_data = pd.merge(player_df, team_df_dropped, 
                       left_on=['team_name', 'Date', 'Opponent'], 
                       right_on=['name', 'Date', 'Opponent'], 
                       how='left')

# %%
player_df
# Out:
#             Date                        Opponent   Result    S  Kills  Errors  \
# 0     2016-09-17                          @ Yale  L 1 - 3  4.0   14.0     3.0
# 1     2016-10-11                         @ UTRGV  L 2 - 3  5.0    8.0     1.0
# 2     2016-10-11                         @ UTRGV  L 2 - 3  5.0   11.0     6.0
# 3     2016-12-02                    @ Washington  L 0 - 3  3.0    5.0     4.0
# 4     2016-09-03       San Diego @ Madison, Wis.  L 0 - 3  3.0    3.0     1.0
# ...          ...                             ...      ...  ...    ...     ...
# 26525 2019-11-22                        Lipscomb  W 3 - 1  4.0    0.0     1.0
# 26526 2018-08-24                    UMass Lowell  W 3 - 0  3.0    6.0     1.0
# 26527 2016-09-13                @ Loyola Chicago  W 3 - 1  4.0   13.0     2.0
# 26528 2018-09-14     Murray St. @ St. Louis, Mo.  W 3 - 1  4.0    0.0     1.0
# 26529 2019-09-14  Saint Francis (PA) @ Akron, OH  W 3 - 0  3.0    1.0     0.0
#
#        Total Attacks  Hit Pct   Assists  SErr  Digs  Block Assists   PTS  \
# 0               37.0    0.297  1.386294   1.0   5.0            3.0  16.5
# 1               20.0    0.350  1.098612   3.0   1.0            6.0  11.0
# 2               44.0    0.114  1.386294   1.0  17.0            3.0  12.5
# 3               30.0    0.033  1.098612   1.0   5.0            1.0   5.5
# 4                7.0    0.286  2.995732   1.0   3.0            3.0   4.5
# ...              ...      ...       ...   ...   ...            ...   ...
# 26525            7.0   -0.143  3.970292   1.0   8.0            1.0   2.5
# 26526           14.0    0.357  1.098612   2.0   2.0            2.0  10.0
# 26527           40.0    0.275  1.098612   4.0   6.0            1.0  13.5
# 26528            1.0   -1.000  3.737670   2.0   6.0            1.0   0.5
# 26529            1.0    1.000  2.772589   1.0   1.0            1.0   2.5
#
#                      name                       team_name
# 0         Carlson, Morgan  A&M-Corpus Christi (Southland)
# 1         Doud, Madeleine  A&M-Corpus Christi (Southland)
# 2        Gilpin, Brittany  A&M-Corpus Christi (Southland)
# 3        Gilpin, Brittany  A&M-Corpus Christi (Southland)
# 4      Nicholson, Kristyn  A&M-Corpus Christi (Southland)
# ...                   ...                             ...
# 26525     Lockey, Chelsey                     FGCU (ASUN)
# 26526       Fezzey, Tyler    Cal St. Fullerton (Big West)
# 26527    Ehrhardt, Alyssa                   UIC (Horizon)
# 26528    Rolda, Antonette                      UNLV (MWC)
# 26529   Alexander, Raegan               Eastern Ky. (OVC)
#
# [26530 rows x 15 columns]

# %%
pd.set_option('display.max_columns', None)
merged_data
# Out:
#             Date                        Opponent Result_x  S_x  Kills_x  \
# 0     2016-09-17                          @ Yale  L 1 - 3  4.0     14.0
# 1     2016-10-11                         @ UTRGV  L 2 - 3  5.0      8.0
# 2     2016-10-11                         @ UTRGV  L 2 - 3  5.0     11.0
# 3     2016-12-02                    @ Washington  L 0 - 3  3.0      5.0
# 4     2016-09-03       San Diego @ Madison, Wis.  L 0 - 3  3.0      3.0
# ...          ...                             ...      ...  ...      ...
# 26525 2019-11-22                        Lipscomb  W 3 - 1  4.0      0.0
# 26526 2018-08-24                    UMass Lowell  W 3 - 0  3.0      6.0
# 26527 2016-09-13                @ Loyola Chicago  W 3 - 1  4.0     13.0
# 26528 2018-09-14     Murray St. @ St. Louis, Mo.  W 3 - 1  4.0      0.0
# 26529 2019-09-14  Saint Francis (PA) @ Akron, OH  W 3 - 0  3.0      1.0
#
#        Errors_x  Total Attacks_x  Hit Pct_x  Assists_x  SErr_x  Digs_x  \
# 0           3.0             37.0      0.297   1.386294     1.0     5.0
# 1           1.0             20.0      0.350   1.098612     3.0     1.0
# 2           6.0             44.0      0.114   1.386294     1.0    17.0
# 3           4.0             30.0      0.033   1.098612     1.0     5.0
# 4           1.0              7.0      0.286   2.995732     1.0     3.0
# ...         ...              ...        ...        ...     ...     ...
# 26525       1.0              7.0     -0.143   3.970292     1.0     8.0
# 26526       1.0             14.0      0.357   1.098612     2.0     2.0
# 26527       2.0             40.0      0.275   1.098612     4.0     6.0
# 26528       1.0              1.0     -1.000   3.737670     2.0     6.0
# 26529       0.0              1.0      1.000   2.772589     1.0     1.0
#
#        Block Assists_x  PTS_x              name_x  \
# 0                  3.0   16.5     Carlson, Morgan
# 1                  6.0   11.0     Doud, Madeleine
# 2                  3.0   12.5    Gilpin, Brittany
# 3                  1.0    5.5    Gilpin, Brittany
# 4                  3.0    4.5  Nicholson, Kristyn
# ...                ...    ...                 ...
# 26525              1.0    2.5     Lockey, Chelsey
# 26526              2.0   10.0       Fezzey, Tyler
# 26527              1.0   13.5    Ehrhardt, Alyssa
# 26528              1.0    0.5    Rolda, Antonette
# 26529              1.0    2.5   Alexander, Raegan
#
#                             team_name Result_y  S_y  Kills_y  Errors_y  \
# 0      A&M-Corpus Christi (Southland)  L 1 - 3  4.0     44.0      24.0
# 1      A&M-Corpus Christi (Southland)  L 2 - 3  5.0     60.0      26.0
# 2      A&M-Corpus Christi (Southland)  L 2 - 3  5.0     60.0      26.0
# 3      A&M-Corpus Christi (Southland)  L 0 - 3  3.0     29.0      22.0
# 4      A&M-Corpus Christi (Southland)  L 0 - 3  3.0     30.0      16.0
# ...                               ...      ...  ...      ...       ...
# 26525                     FGCU (ASUN)  W 3 - 1  4.0     55.0      14.0
# 26526    Cal St. Fullerton (Big West)  W 3 - 0  3.0     40.0      16.0
# 26527                   UIC (Horizon)  W 3 - 1  4.0     52.0      18.0
# 26528                      UNLV (MWC)  W 3 - 1  4.0     47.0      11.0
# 26529               Eastern Ky. (OVC)      NaN  NaN      NaN       NaN
#
#        Total Attacks_y  Hit Pct_y  Assists_y  Aces  SErr_y  Digs_y  RErr  \
# 0                143.0      0.140       38.0   3.0     4.0    56.0   6.0
# 1                187.0      0.182       57.0   2.0     6.0    77.0   6.0
# 2                187.0      0.182       57.0   2.0     6.0    77.0   6.0
# 3                104.0      0.067       28.0   1.0     7.0    37.0   9.0
# 4                 94.0      0.149       29.0   1.0     3.0    32.0   1.0
# ...                ...        ...        ...   ...     ...     ...   ...
# 26525            160.0      0.256       53.0   3.0     8.0    71.0   5.0
# 26526            107.0      0.224       36.0   8.0     6.0    51.0   4.0
# 26527            135.0      0.252       50.0   3.0    10.0    51.0   2.0
# 26528            130.0      0.277       44.0  12.0    17.0    67.0   4.0
# 26529              NaN        NaN        NaN   NaN     NaN     NaN   NaN
#
#        Block Assists_y  PTS_y                          name_y
# 0                 18.0   57.0  A&M-Corpus Christi (Southland)
# 1                 26.0   76.0  A&M-Corpus Christi (Southland)
# 2                 26.0   76.0  A&M-Corpus Christi (Southland)
# 3                  6.0   34.0  A&M-Corpus Christi (Southland)
# 4                 15.0   42.5  A&M-Corpus Christi (Southland)
# ...                ...    ...                             ...
# 26525             22.0   71.0                     FGCU (ASUN)
# 26526             14.0   56.0    Cal St. Fullerton (Big West)
# 26527             16.0   65.0                   UIC (Horizon)
# 26528              6.0   65.0                      UNLV (MWC)
# 26529              NaN    NaN                             NaN
#
# [26530 rows x 29 columns]

# %%
# Let's calculate the performance rates
merged_data['Kill_ratio'] = 100*(merged_data['Kills_x'] / merged_data['Kills_y'])
merged_data['Errors_ratio'] =100*( merged_data['Errors_x'] / merged_data['Errors_y'])
#merged_data['Hit_pct_ratio'] = merged_data['Hit Pct_x'] / merged_data['Hit Pct_y'] # hit_pct_ is already a rate
merged_data['Assists_ratio'] =100*( merged_data['Assists_x'] / merged_data['Assists_y'])
merged_data['Total Attacks_ratio'] =100*( merged_data['Total Attacks_x'] / merged_data['Total Attacks_y'])
merged_data['PTS_ratio'] = 100*(merged_data['PTS_x'] / merged_data['PTS_y'])
merged_data['SErr_ratio'] = 100*(merged_data['SErr_x'] / merged_data['SErr_y'])
merged_data['Digs_ratio'] = 100*(merged_data['Digs_x'] / merged_data['Digs_y'])
merged_data['Block Assists_ratio'] = 100*(merged_data['Block Assists_x'] / merged_data['Block Assists_y'])
#merged_data['S_ratio'] = merged_data['S_x'] / merged_data['S_y'] # don't need to calculate rate of set column

# %%
# Create the new data set and select the necessary columns (select the columns that in player data set)
player_performance_ratios = merged_data[['Date','Opponent','Result_x','S_x', 'Kill_ratio', 'Errors_ratio', 'Total Attacks_ratio','Hit Pct_x', 'Assists_ratio', 
                                         'SErr_ratio', 'Digs_ratio', 'Block Assists_ratio', 
                                         'PTS_ratio', 'name_x','name_y']]

# %%
rows_to_drop = player_performance_ratios[player_performance_ratios.isnull().any(axis=1)].index
# Drop the corresponding rows in the player_df dataset
player_df_cleaned = player_df.drop(rows_to_drop)

player_performance_ratios=player_performance_ratios.dropna() # drop null rows (there is matches which are in player dataset but not in team dataset)
player_performance_ratios = player_performance_ratios.rename(columns={'name_x': 'name', 'name_y': 'team_name'})
player_performance_ratios
# Out:
#             Date                     Opponent Result_x  S_x  Kill_ratio  \
# 0     2016-09-17                       @ Yale  L 1 - 3  4.0   31.818182
# 1     2016-10-11                      @ UTRGV  L 2 - 3  5.0   13.333333
# 2     2016-10-11                      @ UTRGV  L 2 - 3  5.0   18.333333
# 3     2016-12-02                 @ Washington  L 0 - 3  3.0   17.241379
# 4     2016-09-03    San Diego @ Madison, Wis.  L 0 - 3  3.0   10.000000
# ...          ...                          ...      ...  ...         ...
# 26524 2016-10-09                Saint Peter's  W 3 - 0  3.0   13.157895
# 26525 2019-11-22                     Lipscomb  W 3 - 1  4.0    0.000000
# 26526 2018-08-24                 UMass Lowell  W 3 - 0  3.0   15.000000
# 26527 2016-09-13             @ Loyola Chicago  W 3 - 1  4.0   25.000000
# 26528 2018-09-14  Murray St. @ St. Louis, Mo.  W 3 - 1  4.0    0.000000
#
#        Errors_ratio  Total Attacks_ratio  Hit Pct_x  Assists_ratio  \
# 0         12.500000            25.874126      0.297       3.648143
# 1          3.846154            10.695187      0.350       1.927390
# 2         23.076923            23.529412      0.114       2.432095
# 3         18.181818            28.846154      0.033       3.923615
# 4          6.250000             7.446809      0.286      10.330111
# ...             ...                  ...        ...            ...
# 26524     23.529412            16.842105      0.062       3.051701
# 26525      7.142857             4.375000     -0.143       7.491117
# 26526      6.250000            13.084112      0.357       3.051701
# 26527     11.111111            29.629630      0.275       2.197225
# 26528      9.090909             0.769231     -1.000       8.494704
#
#        SErr_ratio  Digs_ratio  Block Assists_ratio  PTS_ratio  \
# 0       25.000000    8.928571            16.666667  28.947368
# 1       50.000000    1.298701            23.076923  14.473684
# 2       16.666667   22.077922            11.538462  16.447368
# 3       14.285714   13.513514            16.666667  16.176471
# 4       33.333333    9.375000            20.000000  10.588235
# ...           ...         ...                  ...        ...
# 26524   16.666667    3.846154            25.000000  16.037736
# 26525   12.500000   11.267606             4.545455   3.521127
# 26526   33.333333    3.921569            14.285714  17.857143
# 26527   40.000000   11.764706             6.250000  20.769231
# 26528   11.764706    8.955224            16.666667   0.769231
#
#                      name                       team_name
# 0         Carlson, Morgan  A&M-Corpus Christi (Southland)
# 1         Doud, Madeleine  A&M-Corpus Christi (Southland)
# 2        Gilpin, Brittany  A&M-Corpus Christi (Southland)
# 3        Gilpin, Brittany  A&M-Corpus Christi (Southland)
# 4      Nicholson, Kristyn  A&M-Corpus Christi (Southland)
# ...                   ...                             ...
# 26524      Ediger, Kelsey                   Marist (MAAC)
# 26525     Lockey, Chelsey                     FGCU (ASUN)
# 26526       Fezzey, Tyler    Cal St. Fullerton (Big West)
# 26527    Ehrhardt, Alyssa                   UIC (Horizon)
# 26528    Rolda, Antonette                      UNLV (MWC)
#
# [23931 rows x 15 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
import numpy as np

target_columns = ['Kill_ratio','Errors_ratio','Total Attacks_ratio','Hit Pct_x','Assists_ratio','SErr_ratio','Digs_ratio','Block Assists_ratio','PTS_ratio']
# Verilerinizi hazırlayalım (Önceden temizlenmiş ve işlenmiş X ve y verisi)
player_df_columns =['Kills', 'Errors', 'Total Attacks',	'Hit Pct','Assists','SErr', 'Digs',	'Block Assists', 'PTS']

# %% [markdown]
# # Regression for Each Column and Try Different ML Models
# ## Using Ratio Values for Prediction Ratios

# %% [markdown]
# ### RANDOM FOREST

# %%
X_full = player_performance_ratios[target_columns]

# RandomForestRegressor modelini kullanmak
for column in target_columns:
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[column])  # Her hedef kolonu çıkararak X oluşturuyoruz
    
    X_train, X_test, y_train, y_test = train_test_split(X, y_column, test_size=0.2, random_state=42)
    
    # Random Forest modelini oluşturun ve eğitin
    model_random_ratio = RandomForestRegressor(n_estimators=100, random_state=42)
    model_random_ratio.fit(X_train, y_train)
    
    y_pred = model_random_ratio.predict(X_test)
    
    # Model değerlendirme metriklerini hesaplayalım
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Sonuçları yazdıralım
    print(f"Değerlendirme sonuçları ({column} için):")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R-squared (R²): {r2:.4f}")
    print("-" * 50)
# Out:
# Değerlendirme sonuçları (Kill_ratio için):
# Mean Squared Error (MSE): 3.1065
# Root Mean Squared Error (RMSE): 1.7625
# Mean Absolute Error (MAE): 1.2630
# R-squared (R²): 0.9726
# --------------------------------------------------
# Değerlendirme sonuçları (Errors_ratio için):
# Mean Squared Error (MSE): 33.7555
# Root Mean Squared Error (RMSE): 5.8100
# Mean Absolute Error (MAE): 3.9746
# R-squared (R²): 0.7834
# --------------------------------------------------
# Değerlendirme sonuçları (Total Attacks_ratio için):
# Mean Squared Error (MSE): 7.1852
# Root Mean Squared Error (RMSE): 2.6805
# Mean Absolute Error (MAE): 1.9050
# R-squared (R²): 0.9305
# --------------------------------------------------
# Değerlendirme sonuçları (Hit Pct_x için):
# Mean Squared Error (MSE): 0.0066
# Root Mean Squared Error (RMSE): 0.0813
# Mean Absolute Error (MAE): 0.0601
# R-squared (R²): 0.8830
# --------------------------------------------------
# Değerlendirme sonuçları (Assists_ratio için):
# Mean Squared Error (MSE): 2.6857
# Root Mean Squared Error (RMSE): 1.6388
# Mean Absolute Error (MAE): 1.0746
# R-squared (R²): 0.7337
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 21
#      19 # Random Forest modelini oluşturun ve eğitin
#      20 model = RandomForestRegressor(n_estimators=100, random_state=42)
# ---> 21 model.fit(X_train, y_train)
#      23 y_pred = model.predict(X_test)
#      25 # Model değerlendirme metriklerini hesaplayalım
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     445 trees = [
#     446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
# --> 456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#     459     prefer="threads",
#     460 )(
#     461     delayed(_parallel_build_trees)(
#     462         t,
#     463         self.bootstrap,
#     464         X,
#     465         y,
#     466         sample_weight,
#     467         i,
#     468         len(trees),
#     469         verbose=self.verbose,
#     470         class_weight=self.class_weight,
#     471         n_samples_bootstrap=n_samples_bootstrap,
#     472     )
#     473     for i, t in enumerate(trees)
#     474 )
#     476 # Collect newly grown trees
#     477 self.estimators_.extend(trees)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     189 else:
#     190     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ### MLP

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

X_full = player_performance_ratios[target_columns]

# RandomForestRegressor modelini kullanarak her hedef kolon için model eğitelim
for column in target_columns:
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[column])  # Her hedef kolonu çıkararak X oluşturuyoruz
    
    # Eksik değerleri medyan ile dolduralı
    
    # Eğitim ve test verilerini bölelim
    X_train, X_test, y_train, y_test = train_test_split(X, y_column, test_size=0.2, random_state=42)
    
    # Yapay Sinir Ağı modelini (MLP) oluşturun
    model_mlp_ratio = MLPRegressor(hidden_layer_sizes=(100,), max_iter=1000, random_state=42)
    
    # Modeli eğitiyoruz
    model_mlp_ratio.fit(X_train, y_train)
    
    # Test verisinde tahmin yapıyoruz
    y_pred = model_mlp_ratio.predict(X_test)
    
    # Model değerlendirme metriklerini hesaplayalım
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Sonuçları yazdıralım
    print(f"Değerlendirme sonuçları ({column} için):")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R-squared (R²): {r2:.4f}")
    print("-" * 50)
# Out:
# Değerlendirme sonuçları (Kill_ratio için):
# Mean Squared Error (MSE): 2.8665
# Root Mean Squared Error (RMSE): 1.6931
# Mean Absolute Error (MAE): 1.2609
# R-squared (R²): 0.9747
# --------------------------------------------------
# Değerlendirme sonuçları (Errors_ratio için):
# Mean Squared Error (MSE): 32.3523
# Root Mean Squared Error (RMSE): 5.6879
# Mean Absolute Error (MAE): 4.0111
# R-squared (R²): 0.7924
# --------------------------------------------------
# Değerlendirme sonuçları (Total Attacks_ratio için):
# Mean Squared Error (MSE): 7.1697
# Root Mean Squared Error (RMSE): 2.6776
# Mean Absolute Error (MAE): 1.9415
# R-squared (R²): 0.9306
# --------------------------------------------------
# Değerlendirme sonuçları (Hit Pct_x için):
# Mean Squared Error (MSE): 0.0100
# Root Mean Squared Error (RMSE): 0.1001
# Mean Absolute Error (MAE): 0.0760
# R-squared (R²): 0.8225
# --------------------------------------------------
# Değerlendirme sonuçları (Assists_ratio için):
# Mean Squared Error (MSE): 2.9948
# Root Mean Squared Error (RMSE): 1.7305
# Mean Absolute Error (MAE): 1.1670
# R-squared (R²): 0.7030
# --------------------------------------------------
# Değerlendirme sonuçları (SErr_ratio için):
# Mean Squared Error (MSE): 167.6422
# Root Mean Squared Error (RMSE): 12.9477
# Mean Absolute Error (MAE): 9.5614
# R-squared (R²): 0.0067
# --------------------------------------------------
# Değerlendirme sonuçları (Digs_ratio için):
# Mean Squared Error (MSE): 39.7911
# Root Mean Squared Error (RMSE): 6.3080
# Mean Absolute Error (MAE): 4.9931
# R-squared (R²): 0.2176
# --------------------------------------------------
# Değerlendirme sonuçları (Block Assists_ratio için):
# Mean Squared Error (MSE): 77.7406
# Root Mean Squared Error (RMSE): 8.8171
# Mean Absolute Error (MAE): 6.5106
# R-squared (R²): 0.2629
# --------------------------------------------------
# Değerlendirme sonuçları (PTS_ratio için):
# Mean Squared Error (MSE): 3.4875
# Root Mean Squared Error (RMSE): 1.8675
# Mean Absolute Error (MAE): 1.4318
# R-squared (R²): 0.9551
# --------------------------------------------------

# %% [markdown]
# ### SVM KERNEL

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
from sklearn.preprocessing import StandardScaler

# Verilerinizi hazırlayalım (Önceden temizlenmiş ve işlenmiş X ve y verisi)
X_full = player_performance_ratios[target_columns]

# RandomForestRegressor modelini kullanarak her hedef kolon için model eğitelim
for column in target_columns:
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[column])  # Her hedef kolonu çıkararak X oluşturuyoruz

    
    # Veriyi normalize etme (SVM modelinin genellikle verilerin ölçeklenmesine ihtiyacı vardır)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Eğitim ve test verilerini bölelim
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_column, test_size=0.2, random_state=42)
    
    # Linear SVM modelini oluşturun
    model_svm_ratio = SVR(kernel='linear')  # Doğrusal kernel kullanıyoruz
    
    # Modeli eğitelim
    model_svm_ratio.fit(X_train, y_train)
    
    # Test verisi üzerinde tahmin yapalım
    y_pred = model_svm_ratio.predict(X_test)
    
    # Model değerlendirme metriklerini hesaplayalım
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Sonuçları yazdıralım
    print(f"Değerlendirme sonuçları ({column} için):")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R-squared (R²): {r2:.4f}")
    print("-" * 50)
# Out:
# Değerlendirme sonuçları (Kill_ratio için):
# Mean Squared Error (MSE): 4.0238
# Root Mean Squared Error (RMSE): 2.0059
# Mean Absolute Error (MAE): 1.5290
# R-squared (R²): 0.9645
# --------------------------------------------------
# Değerlendirme sonuçları (Errors_ratio için):
# Mean Squared Error (MSE): 44.9005
# Root Mean Squared Error (RMSE): 6.7008
# Mean Absolute Error (MAE): 4.9817
# R-squared (R²): 0.7119
# --------------------------------------------------
# Değerlendirme sonuçları (Total Attacks_ratio için):
# Mean Squared Error (MSE): 9.5562
# Root Mean Squared Error (RMSE): 3.0913
# Mean Absolute Error (MAE): 2.3213
# R-squared (R²): 0.9075
# --------------------------------------------------
# Değerlendirme sonuçları (Hit Pct_x için):
# Mean Squared Error (MSE): 0.0343
# Root Mean Squared Error (RMSE): 0.1852
# Mean Absolute Error (MAE): 0.1174
# R-squared (R²): 0.3929
# --------------------------------------------------
# Değerlendirme sonuçları (Assists_ratio için):
# Mean Squared Error (MSE): 4.7362
# Root Mean Squared Error (RMSE): 2.1763
# Mean Absolute Error (MAE): 1.7126
# R-squared (R²): 0.5304
# --------------------------------------------------
# Değerlendirme sonuçları (SErr_ratio için):
# Mean Squared Error (MSE): 174.8268
# Root Mean Squared Error (RMSE): 13.2222
# Mean Absolute Error (MAE): 9.3303
# R-squared (R²): -0.0359
# --------------------------------------------------
# Değerlendirme sonuçları (Digs_ratio için):
# Mean Squared Error (MSE): 42.8386
# Root Mean Squared Error (RMSE): 6.5451
# Mean Absolute Error (MAE): 5.1702
# R-squared (R²): 0.1576
# --------------------------------------------------
# Değerlendirme sonuçları (Block Assists_ratio için):
# Mean Squared Error (MSE): 83.2387
# Root Mean Squared Error (RMSE): 9.1235
# Mean Absolute Error (MAE): 6.5893
# R-squared (R²): 0.2108
# --------------------------------------------------
# Değerlendirme sonuçları (PTS_ratio için):
# Mean Squared Error (MSE): 3.6077
# Root Mean Squared Error (RMSE): 1.8994
# Mean Absolute Error (MAE): 1.4476
# R-squared (R²): 0.9535
# --------------------------------------------------

# %% [markdown]
# ### PCA with Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
# Veriyi hazırlama
X_full = player_performance_ratios[target_columns]

# Hedef kolonu belirleme
for column in target_columns:
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[column])  # Her hedef kolonu çıkararak X oluşturuyoruz
    
    # Veriyi normalize etme
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # PCA ile boyut indirgeme (örneğin 3 ana bileşen seçelim)
    pca = PCA(n_components=3)
    X_pca = pca.fit_transform(X_scaled)
    
    # Eğitim ve test verilerini bölelim
    X_train, X_test, y_train, y_test = train_test_split(X_pca, y_column, test_size=0.2, random_state=42)
    
    # Linear Regression modelini oluşturun
    model_pca_ratio = LinearRegression()
    
    # Modeli eğitelim
    model_pca_ratio.fit(X_train, y_train)
    
    # Test verisi üzerinde tahmin yapalım
    y_pred = model_pca_ratio.predict(X_test)
    
    # Model değerlendirme metriklerini hesaplayalım
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Sonuçları yazdıralım
    print(f"Değerlendirme sonuçları ({column} için):")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R-squared (R²): {r2:.4f}")
    print("-" * 50)
# Out:
# Değerlendirme sonuçları (Kill_ratio için):
# Mean Squared Error (MSE): 11.7575
# Root Mean Squared Error (RMSE): 3.4289
# Mean Absolute Error (MAE): 2.6140
# R-squared (R²): 0.8963
# --------------------------------------------------
# Değerlendirme sonuçları (Errors_ratio için):
# Mean Squared Error (MSE): 49.7522
# Root Mean Squared Error (RMSE): 7.0535
# Mean Absolute Error (MAE): 5.3215
# R-squared (R²): 0.6807
# --------------------------------------------------
# Değerlendirme sonuçları (Total Attacks_ratio için):
# Mean Squared Error (MSE): 10.7891
# Root Mean Squared Error (RMSE): 3.2847
# Mean Absolute Error (MAE): 2.5443
# R-squared (R²): 0.8956
# --------------------------------------------------
# Değerlendirme sonuçları (Hit Pct_x için):
# Mean Squared Error (MSE): 0.0561
# Root Mean Squared Error (RMSE): 0.2368
# Mean Absolute Error (MAE): 0.1635
# R-squared (R²): 0.0073
# --------------------------------------------------
# Değerlendirme sonuçları (Assists_ratio için):
# Mean Squared Error (MSE): 5.3722
# Root Mean Squared Error (RMSE): 2.3178
# Mean Absolute Error (MAE): 1.8288
# R-squared (R²): 0.4673
# --------------------------------------------------
# Değerlendirme sonuçları (SErr_ratio için):
# Mean Squared Error (MSE): 167.7684
# Root Mean Squared Error (RMSE): 12.9525
# Mean Absolute Error (MAE): 9.6637
# R-squared (R²): 0.0060
# --------------------------------------------------
# Değerlendirme sonuçları (Digs_ratio için):
# Mean Squared Error (MSE): 49.6030
# Root Mean Squared Error (RMSE): 7.0429
# Mean Absolute Error (MAE): 5.7406
# R-squared (R²): 0.0246
# --------------------------------------------------
# Değerlendirme sonuçları (Block Assists_ratio için):
# Mean Squared Error (MSE): 102.6772
# Root Mean Squared Error (RMSE): 10.1330
# Mean Absolute Error (MAE): 7.8593
# R-squared (R²): 0.0265
# --------------------------------------------------
# Değerlendirme sonuçları (PTS_ratio için):
# Mean Squared Error (MSE): 11.3719
# Root Mean Squared Error (RMSE): 3.3722
# Mean Absolute Error (MAE): 2.6307
# R-squared (R²): 0.8535
# --------------------------------------------------

# %% [markdown]
# ## Using original values for prediction the ratios

# %% [markdown]
# ### Random Forest

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor

X_full = player_df_cleaned[player_df_columns]

for idx, column in enumerate(target_columns):
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[X_full.columns[idx]])

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_column, test_size=0.2, random_state=42)

    # Random Forest modelini oluşturun ve eğitin
    model_random_original = RandomForestRegressor(n_estimators=100, random_state=42)
    model_random_original.fit(X_train, y_train)
    
    y_pred = model_random_original.predict(X_test)
    
    # Model değerlendirme metriklerini hesaplayalım
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Sonuçları yazdıralım
    print(f"Değerlendirme sonuçları ({column} için):")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R-squared (R²): {r2:.4f}")
    print("-" * 50)
# Out:
# Değerlendirme sonuçları (Kill_ratio için):
# Mean Squared Error (MSE): 14.7385
# Root Mean Squared Error (RMSE): 3.8391
# Mean Absolute Error (MAE): 2.5704
# R-squared (R²): 0.8700
# --------------------------------------------------
# Değerlendirme sonuçları (Errors_ratio için):
# Mean Squared Error (MSE): 30.0874
# Root Mean Squared Error (RMSE): 5.4852
# Mean Absolute Error (MAE): 3.6358
# R-squared (R²): 0.8069
# --------------------------------------------------
# Değerlendirme sonuçları (Total Attacks_ratio için):
# Mean Squared Error (MSE): 12.0449
# Root Mean Squared Error (RMSE): 3.4706
# Mean Absolute Error (MAE): 2.4448
# R-squared (R²): 0.8834
# --------------------------------------------------
# Değerlendirme sonuçları (Hit Pct_x için):
# Mean Squared Error (MSE): 0.0001
# Root Mean Squared Error (RMSE): 0.0077
# Mean Absolute Error (MAE): 0.0020
# R-squared (R²): 0.9990
# --------------------------------------------------
# Değerlendirme sonuçları (Assists_ratio için):
# Mean Squared Error (MSE): 3.3388
# Root Mean Squared Error (RMSE): 1.8272
# Mean Absolute Error (MAE): 1.2364
# R-squared (R²): 0.6689
# --------------------------------------------------
# Değerlendirme sonuçları (SErr_ratio için):
# Mean Squared Error (MSE): 187.0900
# Root Mean Squared Error (RMSE): 13.6781
# Mean Absolute Error (MAE): 10.3845
# R-squared (R²): -0.1085
# --------------------------------------------------
# Değerlendirme sonuçları (Digs_ratio için):
# Mean Squared Error (MSE): 48.0589
# Root Mean Squared Error (RMSE): 6.9325
# Mean Absolute Error (MAE): 5.4559
# R-squared (R²): 0.0550
# --------------------------------------------------
# Değerlendirme sonuçları (Block Assists_ratio için):
# Mean Squared Error (MSE): 97.7293
# Root Mean Squared Error (RMSE): 9.8858
# Mean Absolute Error (MAE): 7.4779
# R-squared (R²): 0.0734
# --------------------------------------------------
# Değerlendirme sonuçları (PTS_ratio için):
# Mean Squared Error (MSE): 14.0266
# Root Mean Squared Error (RMSE): 3.7452
# Mean Absolute Error (MAE): 2.7571
# R-squared (R²): 0.8193
# --------------------------------------------------

# %% [markdown]
# ### MLP Model

# %%
X_full = player_df_cleaned[player_df_columns]

# RandomForestRegressor modelini kullanarak her hedef kolon için model eğitelim
for idx, column in enumerate(target_columns):
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[X_full.columns[idx]])  # Her hedef kolonu çıkararak X oluşturuyoruz
    
    # Eksik değerleri medyan ile dolduralı
    
    # Eğitim ve test verilerini bölelim
    X_train, X_test, y_train, y_test = train_test_split(X, y_column, test_size=0.2, random_state=42)
    
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Yapay Sinir Ağı modelini (MLP) oluşturun
    model_mlp_original = MLPRegressor(hidden_layer_sizes=(100,), max_iter=1000, random_state=42)
    
    # Modeli eğitiyoruz
    model_mlp_original.fit(X_train, y_train)
    
    # Test verisinde tahmin yapıyoruz
    y_pred = model_mlp_original.predict(X_test)
    
    # Model değerlendirme metriklerini hesaplayalım
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Sonuçları yazdıralım
    print(f"Değerlendirme sonuçları ({column} için):")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R-squared (R²): {r2:.4f}")
    print("-" * 50)
# Out:
# Değerlendirme sonuçları (Kill_ratio için):
# Mean Squared Error (MSE): 13.1758
# Root Mean Squared Error (RMSE): 3.6298
# Mean Absolute Error (MAE): 2.3736
# R-squared (R²): 0.8837
# --------------------------------------------------
# Değerlendirme sonuçları (Errors_ratio için):
# Mean Squared Error (MSE): 24.8504
# Root Mean Squared Error (RMSE): 4.9850
# Mean Absolute Error (MAE): 3.2620
# R-squared (R²): 0.8405
# --------------------------------------------------
# Değerlendirme sonuçları (Total Attacks_ratio için):
# Mean Squared Error (MSE): 9.4850
# Root Mean Squared Error (RMSE): 3.0798
# Mean Absolute Error (MAE): 2.1543
# R-squared (R²): 0.9082
# --------------------------------------------------
# Değerlendirme sonuçları (Hit Pct_x için):
# Mean Squared Error (MSE): 0.0007
# Root Mean Squared Error (RMSE): 0.0259
# Mean Absolute Error (MAE): 0.0192
# R-squared (R²): 0.9881
# --------------------------------------------------
# Değerlendirme sonuçları (Assists_ratio için):
# Mean Squared Error (MSE): 0.7606
# Root Mean Squared Error (RMSE): 0.8721
# Mean Absolute Error (MAE): 0.5522
# R-squared (R²): 0.9246
# --------------------------------------------------
# Değerlendirme sonuçları (SErr_ratio için):
# Mean Squared Error (MSE): 118.1721
# Root Mean Squared Error (RMSE): 10.8707
# Mean Absolute Error (MAE): 7.2681
# R-squared (R²): 0.2998
# --------------------------------------------------
# Değerlendirme sonuçları (Digs_ratio için):
# Mean Squared Error (MSE): 10.5078
# Root Mean Squared Error (RMSE): 3.2416
# Mean Absolute Error (MAE): 2.3544
# R-squared (R²): 0.7934
# --------------------------------------------------
# Değerlendirme sonuçları (Block Assists_ratio için):
# Mean Squared Error (MSE): 71.6780
# Root Mean Squared Error (RMSE): 8.4663
# Mean Absolute Error (MAE): 5.9493
# R-squared (R²): 0.3204
# --------------------------------------------------
# Değerlendirme sonuçları (PTS_ratio için):
# Mean Squared Error (MSE): 12.1612
# Root Mean Squared Error (RMSE): 3.4873
# Mean Absolute Error (MAE): 2.5264
# R-squared (R²): 0.8433
# --------------------------------------------------

# %% [markdown]
# ### SVM

# %%
X_full = player_df_cleaned[player_df_columns]

# RandomForestRegressor modelini kullanarak her hedef kolon için model eğitelim
for idx, column in enumerate(target_columns):
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[X_full.columns[idx]])

    
    # Veriyi normalize etme (SVM modelinin genellikle verilerin ölçeklenmesine ihtiyacı vardır)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Eğitim ve test verilerini bölelim
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_column, test_size=0.2, random_state=42)
    
    # Linear SVM modelini oluşturun
    model_svm_original = SVR(kernel='rbf')  # Doğrusal kernel kullanıyoruz
    
    # Modeli eğitelim
    model_svm_original.fit(X_train, y_train)
    
    # Test verisi üzerinde tahmin yapalım
    y_pred = model_svm_original.predict(X_test)
    
    # Model değerlendirme metriklerini hesaplayalım
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Sonuçları yazdıralım
    print(f"Değerlendirme sonuçları ({column} için):")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R-squared (R²): {r2:.4f}")
    print("-" * 50)
# Out:
# Değerlendirme sonuçları (Kill_ratio için):
# Mean Squared Error (MSE): 13.4950
# Root Mean Squared Error (RMSE): 3.6736
# Mean Absolute Error (MAE): 2.3554
# R-squared (R²): 0.8809
# --------------------------------------------------
# Değerlendirme sonuçları (Errors_ratio için):
# Mean Squared Error (MSE): 26.3422
# Root Mean Squared Error (RMSE): 5.1325
# Mean Absolute Error (MAE): 3.1853
# R-squared (R²): 0.8310
# --------------------------------------------------
# Değerlendirme sonuçları (Total Attacks_ratio için):
# Mean Squared Error (MSE): 9.9357
# Root Mean Squared Error (RMSE): 3.1521
# Mean Absolute Error (MAE): 2.1920
# R-squared (R²): 0.9038
# --------------------------------------------------
# Değerlendirme sonuçları (Hit Pct_x için):
# Mean Squared Error (MSE): 0.0011
# Root Mean Squared Error (RMSE): 0.0328
# Mean Absolute Error (MAE): 0.0256
# R-squared (R²): 0.9810
# --------------------------------------------------
# Değerlendirme sonuçları (Assists_ratio için):
# Mean Squared Error (MSE): 0.7468
# Root Mean Squared Error (RMSE): 0.8642
# Mean Absolute Error (MAE): 0.5181
# R-squared (R²): 0.9259
# --------------------------------------------------
# Değerlendirme sonuçları (SErr_ratio için):
# Mean Squared Error (MSE): 125.4697
# Root Mean Squared Error (RMSE): 11.2013
# Mean Absolute Error (MAE): 7.0934
# R-squared (R²): 0.2566
# --------------------------------------------------
# Değerlendirme sonuçları (Digs_ratio için):
# Mean Squared Error (MSE): 10.8681
# Root Mean Squared Error (RMSE): 3.2967
# Mean Absolute Error (MAE): 2.3825
# R-squared (R²): 0.7863
# --------------------------------------------------
# Değerlendirme sonuçları (Block Assists_ratio için):
# Mean Squared Error (MSE): 75.9086
# Root Mean Squared Error (RMSE): 8.7126
# Mean Absolute Error (MAE): 5.6770
# R-squared (R²): 0.2803
# --------------------------------------------------
# Değerlendirme sonuçları (PTS_ratio için):
# Mean Squared Error (MSE): 12.7366
# Root Mean Squared Error (RMSE): 3.5688
# Mean Absolute Error (MAE): 2.5531
# R-squared (R²): 0.8359
# --------------------------------------------------

# %% [markdown]
# ## Using Cross-Validation
# ### Random Forest

# %%
X_full = player_df_cleaned[player_df_columns]
# RandomForestRegressor modelini kullanmak
for idx, column in enumerate(target_columns):
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[X_full.columns[idx]])
    
    # Cross-validation ile modelin değerlendirilmesi
    model_random_cross = RandomForestRegressor(n_estimators=100, random_state=42)
    
    # Cross-validation ile MSE hesaplamak
    # 'scoring' parametresini 'neg_mean_squared_error' olarak ayarlıyoruz, çünkü negative MSE kullanılır
    cv_scores = cross_val_score(model_random_cross, X, y_column, cv=5, scoring='neg_mean_squared_error')
    
    # CV sonuçları (negatif MSE) döndürülecek, bu yüzden pozitif hale getirelim
    cv_scores = -cv_scores  # Negatif olduğu için çeviriyoruz
    
    # Ortalama MSE'yi hesaplayalım
    mean_cv_mse = np.mean(cv_scores)
    mean_cv_rmse = np.sqrt(mean_cv_mse)
    mean_cv_mae = np.mean([mean_absolute_error(y_column, model_random_cross.fit(X, y_column).predict(X)) for _ in range(5)])  # Ortalama MAE hesaplaması için bir yöntem
    mean_cv_r2 = np.mean([r2_score(y_column, model_random_cross.fit(X, y_column).predict(X)) for _ in range(5)])

    # Çapraz doğrulama sonuçlarını yazdıralım
    print(f'Target column {column}, cross-validation results:')
    print(f"Mean Squared Error (MSE) - Cross-validation: {mean_cv_mse}")
    print(f"Root Mean Squared Error (RMSE) - Cross-validation: {mean_cv_rmse}")
    print(f"Mean Absolute Error (MAE) - Cross-validation: {mean_cv_mae}")
    print(f"R-squared (R²) - Cross-validation: {mean_cv_r2}")
    print("-" * 50)
# Out:
# Target column Kill_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 14.942671945297999
# Root Mean Squared Error (RMSE) - Cross-validation: 3.8655752411895956
# Mean Absolute Error (MAE) - Cross-validation: 0.9387007751657315
# R-squared (R²) - Cross-validation: 0.9821696886208894
# --------------------------------------------------
# Target column Errors_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 32.79417574499688
# Root Mean Squared Error (RMSE) - Cross-validation: 5.72661992321796
# Mean Absolute Error (MAE) - Cross-validation: 1.3533633207131281
# R-squared (R²) - Cross-validation: 0.9726743600812366
# --------------------------------------------------
# Target column Total Attacks_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 12.216598648640053
# Root Mean Squared Error (RMSE) - Cross-validation: 3.495225121310508
# Mean Absolute Error (MAE) - Cross-validation: 0.8956748160554737
# R-squared (R²) - Cross-validation: 0.9840555095058537
# --------------------------------------------------
# Target column Hit Pct_x, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 7.230904394734108e-05
# Root Mean Squared Error (RMSE) - Cross-validation: 0.008503472464078489
# Mean Absolute Error (MAE) - Cross-validation: 0.0006965751535666784
# R-squared (R²) - Cross-validation: 0.9998711687740496
# --------------------------------------------------
# Target column Assists_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 3.54432855451426
# Root Mean Squared Error (RMSE) - Cross-validation: 1.882638721187435
# Mean Absolute Error (MAE) - Cross-validation: 0.5088136023926861
# R-squared (R²) - Cross-validation: 0.9382299053738945
# --------------------------------------------------
# Target column SErr_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 187.20716010246187
# Root Mean Squared Error (RMSE) - Cross-validation: 13.682366758074492
# Mean Absolute Error (MAE) - Cross-validation: 3.903477758327489
# R-squared (R²) - Cross-validation: 0.8410456885502404
# --------------------------------------------------
# Target column Digs_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 47.30714911000687
# Root Mean Squared Error (RMSE) - Cross-validation: 6.8780192722910325
# Mean Absolute Error (MAE) - Cross-validation: 2.1311750828079012
# R-squared (R²) - Cross-validation: 0.8432880774665568
# --------------------------------------------------
# Target column Block Assists_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 97.2156525589877
# Root Mean Squared Error (RMSE) - Cross-validation: 9.859799823474496
# Mean Absolute Error (MAE) - Cross-validation: 2.789207392133057
# R-squared (R²) - Cross-validation: 0.8674576213908397
# --------------------------------------------------
# Target column PTS_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 13.966033674760117
# Root Mean Squared Error (RMSE) - Cross-validation: 3.7371156892395128
# Mean Absolute Error (MAE) - Cross-validation: 1.0251309707927572
# R-squared (R²) - Cross-validation: 0.9744439978223323
# --------------------------------------------------

# %% [markdown]
# ### MLP Model

# %%
from sklearn.neural_network import MLPRegressor
X_full = player_df_cleaned[player_df_columns]

# RandomForestRegressor modelini kullanarak her hedef kolon için model eğitelim
for idx, column in enumerate(target_columns):
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[X_full.columns[idx]])
    
    # Yapay Sinir Ağı modelini (MLP) oluşturun
    model_mlp_cross = MLPRegressor(hidden_layer_sizes=(100,), max_iter=1000, random_state=42)

    cv_scores = cross_val_score(model_mlp_cross, X, y_column, cv=5, scoring='neg_mean_squared_error')
    
    # CV sonuçları (negatif MSE) döndürülecek, bu yüzden pozitif hale getirelim
    cv_scores = -cv_scores  # Negatif olduğu için çeviriyoruz
    
    # Ortalama MSE'yi hesaplayalım
    mean_cv_mse = np.mean(cv_scores)
    mean_cv_rmse = np.sqrt(mean_cv_mse)
    mean_cv_mae = np.mean([mean_absolute_error(y_column, model_mlp_cross.fit(X, y_column).predict(X)) for _ in range(5)])  # Ortalama MAE hesaplaması için bir yöntem
    mean_cv_r2 = np.mean([r2_score(y_column, model_mlp_cross.fit(X, y_column).predict(X)) for _ in range(5)])

    # Çapraz doğrulama sonuçlarını yazdıralım
    print(f'Target column {column}, cross-validation results:')
    print(f"Mean Squared Error (MSE) - Cross-validation: {mean_cv_mse}")
    print(f"Root Mean Squared Error (RMSE) - Cross-validation: {mean_cv_rmse}")
    print(f"Mean Absolute Error (MAE) - Cross-validation: {mean_cv_mae}")
    print(f"R-squared (R²) - Cross-validation: {mean_cv_r2}")
    print("\n")
# Out:
# Target column Kill_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 13.439861574586734
# Root Mean Squared Error (RMSE) - Cross-validation: 3.666041676602536
# Mean Absolute Error (MAE) - Cross-validation: 2.3584084638005627
# R-squared (R²) - Cross-validation: 0.8875675878374194
#
#
# Target column Errors_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 28.60933488055615
# Root Mean Squared Error (RMSE) - Cross-validation: 5.348769473491651
# Mean Absolute Error (MAE) - Cross-validation: 3.45992174362767
# R-squared (R²) - Cross-validation: 0.8330920599343743
#
#
# Target column Total Attacks_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 11.58347043700457
# Root Mean Squared Error (RMSE) - Cross-validation: 3.403449784704421
# Mean Absolute Error (MAE) - Cross-validation: 2.341110034580057
# R-squared (R²) - Cross-validation: 0.8954633968689721
#
#
# Target column Hit Pct_x, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 0.0016935660513213418
# Root Mean Squared Error (RMSE) - Cross-validation: 0.04115295920491432
# Mean Absolute Error (MAE) - Cross-validation: 0.036153215960270754
# R-squared (R²) - Cross-validation: 0.9666889124542049
#
#
# Target column Assists_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 3.105462905310057
# Root Mean Squared Error (RMSE) - Cross-validation: 1.7622323641648558
# Mean Absolute Error (MAE) - Cross-validation: 1.1377876097496078
# R-squared (R²) - Cross-validation: 0.7135046726566745
#
#
# Target column SErr_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 171.36804056178977
# Root Mean Squared Error (RMSE) - Cross-validation: 13.090761649414818
# Mean Absolute Error (MAE) - Cross-validation: 9.724640662764434
# R-squared (R²) - Cross-validation: 0.009264250398836604
#
#
# Target column Digs_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 42.114630969612065
# Root Mean Squared Error (RMSE) - Cross-validation: 6.4895786434569125
# Mean Absolute Error (MAE) - Cross-validation: 5.089366961376033
# R-squared (R²) - Cross-validation: 0.17732368673092846
#
#
# Target column Block Assists_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 89.11491009117044
# Root Mean Squared Error (RMSE) - Cross-validation: 9.440069390167132
# Mean Absolute Error (MAE) - Cross-validation: 7.188455115225905
# R-squared (R²) - Cross-validation: 0.1557675385455679
#
#
# Target column PTS_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 12.874900319752566
# Root Mean Squared Error (RMSE) - Cross-validation: 3.588161133471094
# Mean Absolute Error (MAE) - Cross-validation: 2.547654563450819
# R-squared (R²) - Cross-validation: 0.8487048219676169

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVR

X_full = player_df_cleaned[player_df_columns]

# RandomForestRegressor modelini kullanarak her hedef kolon için model eğitelim
for idx, column in enumerate(target_columns):
    y_column = player_performance_ratios[column]
    
    # X (özellikler) ve y (hedef) verilerini ayıralım
    X = X_full.drop(columns=[X_full.columns[idx]])  # Her hedef kolonu çıkararak X oluşturuyoruz
    
    # Veriyi normalize etme (SVM modelinin genellikle verilerin ölçeklenmesine ihtiyacı vardır)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Linear SVM modelini oluşturun
    model_svm_cross = SVR(kernel='rbf')  
    
    cv_scores = cross_val_score(model_svm_cross, X, y_column, cv=5, scoring='neg_mean_squared_error')
    
    # CV sonuçları (negatif MSE) döndürülecek, bu yüzden pozitif hale getirelim
    cv_scores = -cv_scores  # Negatif olduğu için çeviriyoruz

    # Ortalama MSE'yi hesaplayalım
    mean_cv_mse = np.mean(cv_scores)
    mean_cv_rmse = np.sqrt(mean_cv_mse)
    mean_cv_mae = np.mean([mean_absolute_error(y_column, model_svm_cross.fit(X, y_column).predict(X)) for _ in range(5)])  # Ortalama MAE hesaplaması için bir yöntem
    mean_cv_r2 = np.mean([r2_score(y_column, model_svm_cross.fit(X, y_column).predict(X)) for _ in range(5)])

    # Çapraz doğrulama sonuçlarını yazdıralım
    print(f'Target column {column}, cross-validation results:')
    print(f"Mean Squared Error (MSE) - Cross-validation: {mean_cv_mse}")
    print(f"Root Mean Squared Error (RMSE) - Cross-validation: {mean_cv_rmse}")
    print(f"Mean Absolute Error (MAE) - Cross-validation: {mean_cv_mae}")
    print(f"R-squared (R²) - Cross-validation: {mean_cv_r2}")
    print("\n")
# Out:
# Target column Kill_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 16.57870881063443
# Root Mean Squared Error (RMSE) - Cross-validation: 4.071696060689505
# Mean Absolute Error (MAE) - Cross-validation: 2.7974317789687886
# R-squared (R²) - Cross-validation: 0.8609980668280126
#
#
# Target column Errors_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 63.8633020784122
# Root Mean Squared Error (RMSE) - Cross-validation: 7.991451812931878
# Mean Absolute Error (MAE) - Cross-validation: 5.710655198431234
# R-squared (R²) - Cross-validation: 0.6130442809865954
#
#
# Target column Total Attacks_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 15.162784881495957
# Root Mean Squared Error (RMSE) - Cross-validation: 3.8939420747484106
# Mean Absolute Error (MAE) - Cross-validation: 2.763400830219959
# R-squared (R²) - Cross-validation: 0.8588106912943532
#
#
# Target column Hit Pct_x, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 0.008621798747563037
# Root Mean Squared Error (RMSE) - Cross-validation: 0.09285364154174588
# Mean Absolute Error (MAE) - Cross-validation: 0.05095441327782595
# R-squared (R²) - Cross-validation: 0.8600008336597881
#
#
# Target column Assists_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 3.2788076971073847
# Root Mean Squared Error (RMSE) - Cross-validation: 1.8107478281382487
# Mean Absolute Error (MAE) - Cross-validation: 1.1870439744114174
# R-squared (R²) - Cross-validation: 0.6920715229004841
#
#
# Target column SErr_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 180.3807494646528
# Root Mean Squared Error (RMSE) - Cross-validation: 13.430590063904594
# Mean Absolute Error (MAE) - Cross-validation: 9.484915306850926
# R-squared (R²) - Cross-validation: -0.045785606225775766
#
#
# Target column Digs_ratio, cross-validation results:
# Mean Squared Error (MSE) - Cross-validation: 43.18535703527569
# Root Mean Squared Error (RMSE) - Cross-validation: 6.571556667584606
# Mean Absolute Error (MAE) - Cross-validation: 5.1158140380755945
# R-squared (R²) - Cross-validation: 0.14320450717804267

# %% [markdown]
# # Save The Model

# %%
# save edeceğin modeli çalıltırırken bunu ekle
    # Dosya yolu
    file_path = f'pkl_files_regression/randomForest_model_{X_full.columns[idx]}.pkl'

    # Klasör yoksa oluştur
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    # Modeli kaydet
    with open(file_path, 'wb') as f:
        pickle.dump(model_random_original, f)
