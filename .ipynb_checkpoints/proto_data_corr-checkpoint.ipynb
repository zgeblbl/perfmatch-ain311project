# %%
import pandas as pd
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = r'proto_data'  # Dosyaların bulunduğu dizin

# Dizin içindeki tüm CSV dosyalarını listele
all_files = glob.glob(path + "/*.csv")

# Her dosyayı okurken ilk satırı atla (skiprows=1 ile)
df_list = [pd.read_csv(f, skiprows=1) for f in all_files]

# Tüm DataFrame'leri birleştir
combined_df = pd.concat(df_list, ignore_index=True)
# Bütün kolonları float türüne çevir

# %%
combined_df
# Out:
#            Date                            Opponent   Result  S  MP Kills  \
# 0    08/26/2016   Sacramento St. @ Arlington, Texas  L 0 - 3  3 NaN    16
# 1    08/27/2016                      @ UT Arlington  L 0 - 3  3 NaN    19
# 2    08/27/2016  Sam Houston St. @ Arlington, Texas  L 0 - 3  3 NaN    23
# 3    09/02/2016                       @ Little Rock  L 0 - 3  3 NaN    28
# 4    09/03/2016       UT Martin @ Little Rock, Ark.  L 0 - 3  3 NaN    26
# ..          ...                                 ...      ... ..  ..   ...
# 275  10/29/2016                          Valparaiso  L 1 - 3  4 NaN    47
# 276  11/04/2016                           @ Oakland  L 0 - 3  3 NaN    25
# 277  11/06/2016                     @ Cleveland St.  L 0 - 3  3 NaN    38
# 278  11/09/2016                        Northern Ky.  L 1 - 3  4 NaN    51
# 279  11/11/2016                               @ UIC  W 3 - 2  5 NaN    60
#
#     Errors Total Attacks  Hit Pct Assists Aces SErr  Digs  RErr Block Solos  \
# 0       20            93   -0.043      16    2    1    30   7.0         NaN
# 1       29            92   -0.109      19    1    2    28   4.0         1.0
# 2       10            86    0.151      22    2    5    30   8.0         NaN
# 3       20            74    0.108      26    3    2    29  16.0         NaN
# 4       17            94    0.096      25    1    5    42   9.0         1.0
# ..     ...           ...      ...     ...  ...  ...   ...   ...         ...
# 275     30           142    0.120      47    4    8    57   6.0           3
# 276     19           105    0.057      23    3    4    39   5.0         NaN
# 277     20           112    0.161      36    5    4    34   3.0           1
# 278     19           144    0.222      49    7    6    61   7.0         NaN
# 279     24           166    0.217      55    2    7    75   6.0           2
#
#      Block Assists BErr   PTS  BHE  Unnamed: 19
# 0              8.0  3.0  22.0  2.0          NaN
# 1              NaN  2.0  21.0  1.0          NaN
# 2              4.0  6.0  27.0  2.0          NaN
# 3              9.0  2.0  35.5  1.0          NaN
# 4              4.0  2.0  30.0  NaN          NaN
# ..             ...  ...   ...  ...          ...
# 275           22.0    1  65.0  2.0          NaN
# 276           16.0    3  36.0  1.0          NaN
# 277            4.0    3  46.0  NaN          NaN
# 278           18.0    3  67.0  NaN          NaN
# 279           10.0    3  69.0  1.0          NaN
#
# [280 rows x 20 columns]

# %%
combined_df.drop(['MP','Unnamed: 19','Date','Opponent'],  axis='columns', inplace=True)

# %%
combined_df
# Out:
#       Result  S Kills Errors Total Attacks  Hit Pct Assists Aces SErr  Digs  \
# 0    L 0 - 3  3    16     20            93   -0.043      16    2    1    30
# 1    L 0 - 3  3    19     29            92   -0.109      19    1    2    28
# 2    L 0 - 3  3    23     10            86    0.151      22    2    5    30
# 3    L 0 - 3  3    28     20            74    0.108      26    3    2    29
# 4    L 0 - 3  3    26     17            94    0.096      25    1    5    42
# ..       ... ..   ...    ...           ...      ...     ...  ...  ...   ...
# 275  L 1 - 3  4    47     30           142    0.120      47    4    8    57
# 276  L 0 - 3  3    25     19           105    0.057      23    3    4    39
# 277  L 0 - 3  3    38     20           112    0.161      36    5    4    34
# 278  L 1 - 3  4    51     19           144    0.222      49    7    6    61
# 279  W 3 - 2  5    60     24           166    0.217      55    2    7    75
#
#      RErr Block Solos  Block Assists BErr   PTS  BHE
# 0     7.0         NaN            8.0  3.0  22.0  2.0
# 1     4.0         1.0            NaN  2.0  21.0  1.0
# 2     8.0         NaN            4.0  6.0  27.0  2.0
# 3    16.0         NaN            9.0  2.0  35.5  1.0
# 4     9.0         1.0            4.0  2.0  30.0  NaN
# ..    ...         ...            ...  ...   ...  ...
# 275   6.0           3           22.0    1  65.0  2.0
# 276   5.0         NaN           16.0    3  36.0  1.0
# 277   3.0           1            4.0    3  46.0  NaN
# 278   7.0         NaN           18.0    3  67.0  NaN
# 279   6.0           2           10.0    3  69.0  1.0
#
# [280 rows x 16 columns]

# %%
df_no_result=combined_df.drop(['Result'],  axis='columns')
df_no_result = df_no_result.apply(pd.to_numeric, errors='coerce')

# %%
correlation_matrix = df_no_result.corr()

# Korelasyon matrisini yazdır
print(correlation_matrix)

# Korelasyon matrisini görselleştir
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Korelasyon Matrisi")
plt.show()
# Out:
#                       S     Kills    Errors  Total Attacks   Hit Pct  \
# S              1.000000  0.733088  0.618765       0.838959 -0.063784
# Kills          0.733088  1.000000  0.338558       0.771512  0.439553
# Errors         0.618765  0.338558  1.000000       0.676648 -0.597642
# Total Attacks  0.838959  0.771512  0.676648       1.000000 -0.138631
# Hit Pct       -0.063784  0.439553 -0.597642      -0.138631  1.000000
# Assists        0.739984  0.986649  0.356007       0.770331  0.417502
# Aces           0.225476  0.179021  0.049051       0.092877  0.163459
# SErr           0.467453  0.409687  0.242689       0.355751  0.113352
# Digs           0.678641  0.699377  0.497876       0.882893 -0.004369
# RErr           0.209614 -0.055125  0.244812       0.126001 -0.346627
# Block Solos    0.063777  0.060578 -0.068735       0.029748  0.083488
# Block Assists  0.395119  0.391644  0.149549       0.336247  0.122072
# BErr           0.127975  0.179825  0.021449       0.168408  0.026728
# PTS            0.755933  0.959868  0.325052       0.747669  0.433395
# BHE            0.071729 -0.078185  0.144677       0.086225 -0.173705
#
#                 Assists      Aces      SErr      Digs      RErr  Block Solos  \
# S              0.739984  0.225476  0.467453  0.678641  0.209614     0.063777
# Kills          0.986649  0.179021  0.409687  0.699377 -0.055125     0.060578
# Errors         0.356007  0.049051  0.242689  0.497876  0.244812    -0.068735
# Total Attacks  0.770331  0.092877  0.355751  0.882893  0.126001     0.029748
# Hit Pct        0.417502  0.163459  0.113352 -0.004369 -0.346627     0.083488
# Assists        1.000000  0.165176  0.397074  0.709700 -0.061884     0.023729
# Aces           0.165176  1.000000  0.209061  0.055067 -0.039984     0.160742
# SErr           0.397074  0.209061  1.000000  0.263498 -0.000263     0.037590
# Digs           0.709700  0.055067  0.263498  1.000000  0.047282     0.076420
# RErr          -0.061884 -0.039984 -0.000263  0.047282  1.000000    -0.024034
# Block Solos    0.023729  0.160742  0.037590  0.076420 -0.024034     1.000000
# Block Assists  0.378898  0.058387  0.074760  0.249134 -0.089861    -0.139199
# BErr           0.180596 -0.008551 -0.038629  0.098826  0.043386     0.048342
# PTS            0.945739  0.331208  0.417609  0.671883 -0.083215     0.141972
# BHE           -0.058168 -0.002891  0.070834  0.166482  0.068058    -0.033817
#
#                Block Assists      BErr       PTS       BHE
# S                   0.395119  0.127975  0.755933  0.071729
# Kills               0.391644  0.179825  0.959868 -0.078185
# Errors              0.149549  0.021449  0.325052  0.144677
# Total Attacks       0.336247  0.168408  0.747669  0.086225
# Hit Pct             0.122072  0.026728  0.433395 -0.173705
# Assists             0.378898  0.180596  0.945739 -0.058168
# Aces                0.058387 -0.008551  0.331208 -0.002891
# SErr                0.074760 -0.038629  0.417609  0.070834
# Digs                0.249134  0.098826  0.671883  0.166482
# RErr               -0.089861  0.043386 -0.083215  0.068058
# Block Solos        -0.139199  0.048342  0.141972 -0.033817
# Block Assists       1.000000  0.169928  0.524118 -0.123561
# BErr                0.169928  1.000000  0.169831 -0.106218
# PTS                 0.524118  0.169831  1.000000 -0.083371
# BHE                -0.123561 -0.106218 -0.083371  1.000000

# %% [markdown]
# * S (Sets Played): Bir takımın oynadığı set sayısını gösterir. Voleybol maçlarında genellikle 3 veya 5 set oynanır.
#
# * Kills: Bir oyuncunun rakip takımın defansını aşarak, doğrudan sayı kazandıran hücum vuruşlarının sayısını gösterir. Yani, başarılı hücumlar.
#
# * Errors: Bir oyuncunun hücum sırasında yaptığı hatalar. Bu, topun rakip takım tarafından kurtarılamayacak şekilde dışarıya gitmesi veya bloklanması gibi hataları içerir.
#
# * Total Attacks: Bir oyuncunun toplam hücum denemelerinin sayısıdır. Kills ve Errors da dahil olmak üzere yapılan tüm hücumlar bu kategoriye girer.
#
# * Hit Pct (Hit Percentage): Hücum yüzdesi. Kills sayısının, toplam hücum denemelerine (Total Attacks) bölünmesiyle elde edilir ve hücumların ne kadarının başarılı olduğunu gösterir. Yüksek bir yüzdelik, oyuncunun etkili bir hücum gücüne sahip olduğunu gösterir.
#
# * Assists: Bir oyuncunun, takım arkadaşına hücum yapması için verdiği pas sayısını ifade eder. Bir oyuncu, topu takım arkadaşına ileterek onların sayı yapmasını sağlar.
#
# * Aces: Bir oyuncunun servis sırasında doğrudan sayı kazandıran vuruşlarının sayısıdır. Rakip takımın servisi karşılayamaması durumunda ace sayılır.
#
# * SErr (Serve Errors): Bir oyuncunun servis sırasında yaptığı hataların sayısıdır. Bu, servisin yanlış yere gitmesi veya servisin dışarı çıkması gibi durumları içerir.
#
# * Digs: Bir oyuncunun rakip takımın hücumlarını başarılı bir şekilde karşılaması (topu rakip sahaya geçmeden önce kurtarma) sayısıdır.
#
# * RErr (Reception Errors): Bir oyuncunun rakip servisini karşılamadığında yapılan hataların sayısıdır. Bu, topun yere düşmesi veya dışarı gitmesi gibi hataları içerir.
#
# * Block Solos: Bir oyuncunun tek başına yaptığı başarılı blokların sayısıdır. Bu, rakip hücumunu tamamen engelleyen bir bloktur.
#
# * Block Assists: Bir oyuncunun takım arkadaşıyla birlikte yaptığı blokların sayısıdır. Birden fazla oyuncu blok yaparsa, bu sayı her iki oyuncuya da yazılır.
#
# * BErr (Block Errors): Bir oyuncunun blok yaparken yaptığı hataların sayısıdır. Bu, rakip takımın blokta başarılı olması veya oyuncunun hatalı bir blok yapması durumunda meydana gelir.
#
# * PTS (Points): Bir oyuncunun veya takımın kazandığı toplam puan sayısıdır. Bu, hücumlardan, servislerden, bloklardan ve diğer oyun öğelerinden elde edilen puanları içerir.
#
# * BHE (Ball Handling Errors): Bir oyuncunun topu kontrol ederken yaptığı hataların sayısıdır. Bu, özellikle pas verme veya topu düzgün bir şekilde tutma hatalarını içerir.

# %% [markdown]
# ### Yorumlama
# * Kills ve Assists arasında yüksek pozitif korelasyon (0.99): Voleybolda oyuuncular çoğu zaman asistle sayı kazanılıyormuş bu korelasyon şaşırtmadı çünkü voleybol paslaşmaya dayanan bir oyundur.
# * PTS ve Kills arasında yüksek pozitif korelasyon (0.96): Kills sayısı ile toplam puanlar (PTS) arasında güçlü bir ilişki vardır. Bu, bir takımın veya oyuncunun kazandığı puanların büyük kısmının doğrudan hücumlardan (kills) geldiğini gösterir.
# * Total Attacks ile Kills arasındaki pozitif korelasyon (0.84): Toplam hücumlar (Total Attacks) ile öldürme sayısı (Kills) arasındaki pozitif korelasyon, bir oyuncunun veya takımın hücum yapma sıklığının, başarılı hücumlarla (Kills) doğrudan ilişkili olduğunu gösterir.

# %%
df_win = combined_df[combined_df['Result'].str.startswith('W')]

# Separate rows where 'Result' starts with 'L'
df_loss = combined_df[combined_df['Result'].str.startswith('L')]

# %%
df_win
# Out:
#       Result  S Kills Errors Total Attacks  Hit Pct Assists Aces SErr  Digs  \
# 11   W 3 - 2  5    53     29           157    0.153      46    6   10    71
# 12   W 3 - 1  4    43     17           121    0.215      42    9    4    68
# 13   W 3 - 1  4    52     19           132    0.250      49    8    7    55
# 15   W 3 - 1  4    42     30           156    0.077      35    5    9    69
# 18   W 3 - 1  4    41     20           127    0.165      35    5   10    63
# ..       ... ..   ...    ...           ...      ...     ...  ...  ...   ...
# 258  W 3 - 0  3    41      5            92    0.391      39    4    7    44
# 259  W 3 - 1  4    48     16           114    0.281      43  17/    4    52
# 260  W 3 - 1  4    61     30           195    0.159      58    7   10    89
# 266  W 3 - 2  5    56     31           192    0.130      51    3  16/    88
# 279  W 3 - 2  5    60     24           166    0.217      55    2    7    75
#
#      RErr Block Solos  Block Assists BErr   PTS  BHE
# 11   10.0         8.0            4.0  2.0  69.0  NaN
# 12    7.0         4.0            NaN  1.0  56.0  7.0
# 13    8.0         3.0            6.0  NaN  66.0  NaN
# 15    5.0         1.0           20.0  NaN  58.0  NaN
# 18   16.0         1.0           10.0  NaN  52.0  1.0
# ..    ...         ...            ...  ...   ...  ...
# 258   2.0           4            6.0    1  52.0  NaN
# 259   3.0           3            6.0    3  71.0  NaN
# 260   7.0          7/           10.0    5  80.0  2.0
# 266   7.0           3           20.0  10/  72.0  NaN
# 279   6.0           2           10.0    3  69.0  1.0
#
# [149 rows x 16 columns]

# %%
df_no_result_win=df_win.drop(['Result'],  axis='columns')
df_no_result_win = df_no_result_win.apply(pd.to_numeric, errors='coerce')

# %%
correlation_matrix_win = df_no_result_win.corr()


# Korelasyon matrisini görselleştir
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_win, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Korelasyon Matrisi kazanılan maçlar için")
plt.show()

# %%
df_loss
# Out:
#       Result  S Kills Errors Total Attacks  Hit Pct Assists Aces SErr  Digs  \
# 0    L 0 - 3  3    16     20            93   -0.043      16    2    1    30
# 1    L 0 - 3  3    19     29            92   -0.109      19    1    2    28
# 2    L 0 - 3  3    23     10            86    0.151      22    2    5    30
# 3    L 0 - 3  3    28     20            74    0.108      26    3    2    29
# 4    L 0 - 3  3    26     17            94    0.096      25    1    5    42
# ..       ... ..   ...    ...           ...      ...     ...  ...  ...   ...
# 274  L 0 - 3  3    46     27           121    0.157      43    4   11    50
# 275  L 1 - 3  4    47     30           142    0.120      47    4    8    57
# 276  L 0 - 3  3    25     19           105    0.057      23    3    4    39
# 277  L 0 - 3  3    38     20           112    0.161      36    5    4    34
# 278  L 1 - 3  4    51     19           144    0.222      49    7    6    61
#
#      RErr Block Solos  Block Assists BErr   PTS  BHE
# 0     7.0         NaN            8.0  3.0  22.0  2.0
# 1     4.0         1.0            NaN  2.0  21.0  1.0
# 2     8.0         NaN            4.0  6.0  27.0  2.0
# 3    16.0         NaN            9.0  2.0  35.5  1.0
# 4     9.0         1.0            4.0  2.0  30.0  NaN
# ..    ...         ...            ...  ...   ...  ...
# 274   2.0           1           12.0    1  57.0  3.0
# 275   6.0           3           22.0    1  65.0  2.0
# 276   5.0         NaN           16.0    3  36.0  1.0
# 277   3.0           1            4.0    3  46.0  NaN
# 278   7.0         NaN           18.0    3  67.0  NaN
#
# [131 rows x 16 columns]

# %%
df_no_result_loss=df_loss.drop(['Result'],  axis='columns')
df_no_result_loss = df_no_result_loss.apply(pd.to_numeric, errors='coerce')

# %%
correlation_matrix_loss = df_no_result_loss.corr()


# Korelasyon matrisini görselleştir
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_loss, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Korelasyon Matrisi kaybedilen maçlar için")
plt.show()

# %% [markdown]
# -gpt-
# Kazanılan Maçlar:
#
# Hücum Performansı Belirleyici: Kills (saldırılar), Assists (asistler) ve PTS (puan) arasındaki yüksek korelasyon, galibiyetlerin hücum temelli bir oyun ile kazanıldığını göstermektedir.
# Düşük Hata Etkisi: Errors (hatalar) ile diğer değişkenler arasında düşük ilişki, hataların galibiyet üzerinde fazla etkili olmadığını işaret etmektedir.
# Savunmanın Rolü: Digs (kurtarışlar) ve Total Attacks (toplam hücumlar) arasında pozitif ilişki, takımın savunmada da başarılı olduğunu gösterir.
# Kaybedilen Maçlar:
#
# Hataların Etkisi: Errors (hatalar) ve SErr (servis hataları) kayıplarda daha belirgin bir rol oynamaktadır.
# Blokların Artan Önemi: Kaybedilen maçlarda Block Assists (yardımlı bloklar) ile puanlar arasında artan bir ilişki, savunma çabalarının sonuç vermediğini ortaya koymaktadır.
# Savunma Eksikliği: Digs ile Total Attacks arasında güçlü bir ilişki olsa da, bu savunmanın kayıpları önlemek için yeterli olmadığını göstermektedir.
# Strateji Önerisi:
#
# Kazanmak İçin: Hücum etkinliğini (Kills, Assists, PTS) artırmaya odaklanılmalı.
# Kaybetmemek İçin: Hataları (Errors, SErr) azaltmaya ve savunma başarısını artırmaya yönelik stratejiler geliştirilmelidir.
